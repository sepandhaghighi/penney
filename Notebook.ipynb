# %% [markdown]
# ## Penney's Game

# %%
from penney.functions import menu_handler

# %%
menu_handler()
# Out:
#  __  __  _____  _   _  _   _
# |  \/  || ____|| \ | || | | |  _
# | |\/| ||  _|  |  \| || | | | (_)
# | |  | || |___ | |\  || |_| |  _
# |_|  |_||_____||_| \_| \___/  (_)
#
#
# - Play with computer [1]
# - Play with other players [any other key]
# Please select : 1
# ###########
# - Fast simulation [1]
# - Step by step [any other key]
# Please select : 1
# ###########
# Please enter number of rounds : 3
# Please enter sequence length : 3
# Please enter player-1 name : Sepand
# [Sepand] Please enter your sequence : HHT
# Computer sequence : THT
# ###########
# Wining Probability :
# Sepand       62.500%
# Computer     37.500%
# Winner should be Sepand
# ###########
# Scores Table :
# Sepand       2   HHT
# Computer     1   THT
# Winner : Sepand
